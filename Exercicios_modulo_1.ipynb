# %% [markdown]
# Exercício 1

# %%
"Olá mundo!"
print ("Olá mundo!")
# Out:
# Olá mundo!

# %% [markdown]
# ![anticorpo.jpg](data:image/jpeg;base64,...)
#
# "Estrutura 3D de um anticorpo!"
# print ("Estrutura 3D de um anticorpo!")

# %% [markdown]
# Exercício 2

# %% [markdown]
# ![Sem título.jpg](data:image/jpeg;base64,...)

# %%
valor_total_vendas = 'A' 
qtd_total_vendas = 3 
ticket_medio = 320.52 

valor_total_vendas = qtd_total_vendas * ticket_medio
print (valor_total_vendas)
# Out:
# 961.56

# %%
valor_total_vendas = 834.47 
qtd_total_vendas = 'B' 
ticket_medio = 119.21

qtd_total_vendas = valor_total_vendas / ticket_medio
print (qtd_total_vendas)
# Out:
# 7.000000000000001

# %%
valor_total_vendas = 15378.12 
qtd_total_vendas = 5 
ticket_medio = 'C'

ticket_medio = valor_total_vendas / qtd_total_vendas
print(ticket_medio)
# Out:
# 3075.6240000000003

# %% [markdown]
# Exercício 3

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

# maiusculo: string.upper () 
print (cancao.upper())
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.' 

# substituição: string.replace(antigo, novo)
print (cancao.replace ("mundo", "planeta"))
# Out:
# Roda planeta, roda gigante, roda moinho, roda pião.

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.' 

# split(',')
print (cancao.split ())
# Out:
# ['Roda', 'mundo,', 'roda', 'gigante,', 'roda', 'moinho,', 'roda', 'pião.']

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; ' + '\n' 'é a primeira alta em 6 anos.'

print('valor_selic: '+noticia[12:18])

# posicao: string.find(substring)
posicao = noticia.find ("anos") 
print (posicao)
# Out:
# valor_selic: 2,75%
# 65

# %% [markdown]
# exercício 4

# %%
a = False
b = True
x = not a & b 


print (x)
# Out:
# True
